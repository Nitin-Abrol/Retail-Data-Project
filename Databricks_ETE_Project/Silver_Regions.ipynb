# %%
df = spark.read.table("dbcatalog.bronze.regions")

# %%
df.display()

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta").mode("overwrite").save("abfss://silver@storageaccnitin.dfs.core.windows.net/regions")

# %%
df = spark.read.format("delta").load("abfss://silver@storageaccnitin.dfs.core.windows.net/products")
df.display()

# %%
# %sql
create table if not exists dbcatalog.silver.regions_silver
using delta
location 'abfss://silver@storageaccnitin.dfs.core.windows.net/regions'

# %%
# %sql
select * from dbcatalog.silver.regions_silver

# %%
# %sql
select * from dbcatalog.silver.customers_silver
